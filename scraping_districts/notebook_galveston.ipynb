# %%
import pandas as pd
import numpy as np
import feedparser
from bs4 import BeautifulSoup
import requests
import PyPDF2 as pdf
import io
import os
import re
import weblist
import scrape_pdf

# %% [markdown]
# ## Step 1: Scrape the list of webpages

# %%
galveston_url = "https://www.swg.usace.army.mil/Media/Public-Notices/"
web_list = weblist.get_web_list(galveston_url)

# Save the weblist to csv to avoid repetitive running
web_list.to_csv("galveston_weblist.csv")
# Out:
#                                                web_link  \
# 0     http://www.swg.usace.army.mil/Media/Public-Not...
# 1     http://www.swg.usace.army.mil/Media/Public-Not...
# 2     http://www.swg.usace.army.mil/Media/Public-Not...
# 3     http://www.swg.usace.army.mil/Media/Public-Not...
# 4     http://www.swg.usace.army.mil/Media/Public-Not...
# ...                                                 ...
# 1086  http://www.swg.usace.army.mil/Media/Public-Not...
# 1087  http://www.swg.usace.army.mil/Media/Public-Not...
# 1088  http://www.swg.usace.army.mil/Media/Public-Not...
# 1089  http://www.swg.usace.army.mil/Media/Public-Not...
# 1090  http://www.swg.usace.army.mil/Media/Public-Not...
#
#                                               web_title published_date  \
# 0     SWG-1992-02709 - Cedar Marine Terminals (subsi...       9/5/2023
# 1     SWG-2003-02165 - TEXAS DEPARTMENT OF TRANSPORT...       9/5/2023
# 2     SWG-2021-00499 - Venture Global CP2 LNG, LLC -...      8/24/2023
# ...

# %%
web_list = pd.read_csv("galveston_weblist.csv")
web_list_sub = web_list.loc[:99]

# %% [markdown]
# ## Step2: Scrap PDFs

# %%
# single test
pdf_url = "https://www.swg.usace.army.mil/Portals/26/docs/regulatory/PN%20July/PN_2023-00264.pdf?ver=TVBq0gfJfr_Tk8eN82N4NA%3d%3d" 
# "https://www.swg.usace.army.mil/Portals/26/docs/regulatory/PN%20APRIL/PN_202100133r.pdf?ver=nVltuPZhaVU9FcQ_wknsnw%3d%3d" 
# pdf_bytes = requests.get(pdf_url).content
# pdf_reader = pdf.PdfReader(io.BytesIO(pdf_bytes))
# pdf_p = pdf_reader.pages[1].extract_text().replace("\n", "")
# pdf_p
pdf_text = scrape_pdf.pdf_read(pdf_url, "galveston")
pdf_text
# scrape_pdf.get_pdf_app_num_dist(pdf_text, "galveston")
# scrape_pdf.get_pdf_manager(pdf_text, "galveston")
# scrape_pdf.get_pdf_applicant(pdf_text, "galveston")
# pdf_location = scrape_pdf.get_pdf_location(pdf_text, "galveston")
# pdf_location
# pdf_character = scrape_pdf.get_pdf_character(pdf_text, "galveston")
# pdf_character
# scrape_pdf.get_pdf_acreage(pdf_character)
# scrape_pdf.get_pdf_linear_feet(pdf_character)
# scrape_pdf.get_pdf_mitigation(pdf_text, "galveston")
# scrape_pdf.get_pdf_city_county_parish(pdf_location)
# scrape_pdf.get_lon_lat_SAJ_SWG(pdf_text)
# scrape_pdf.pdf_extraction(pdf_url, "galveston")
# Out:
# ['26.96794']

# %%
pdf_df = pd.DataFrame([scrape_pdf.pdf_extraction(x, "galveston") for x in web_list_sub["pdf_url"]],
                            columns = ['pdf_special',
                                       'pdf_comment_window',
                                       'pdf_permit_app_num',
                                       'pdf_dist_code',
                                       'pdf_dist_name',  
                                       'pdf_manager_name', 
                                       'pdf_manager_phone', 
                                       'pdf_manager_email',
                                       'pdf_applicant_contents',
                                       'pdf_applicant',
                                       'pdf_contract',
                                       'pdf_location', 
                                       'pdf_character', 
                                       'pdf_mitigation',
                                       'pdf_county',
                                       'pdf_parish',
                                       'pdf_city',
                                       'pdf_hydrologic_unit_code', 
                                       'pdf_longitude',
                                       'pdf_latitude',
                                       'pdf_wqc',
                                       'pdf_cup',
                                       # 'pdf_acre1',
                                       # 'pdf_acre_type1', 
                                       # 'pdf_acre_term1',
                                       # 'pdf_acre2',
                                       # 'pdf_acre_type2', 
                                       # 'pdf_acre_term2', 
                                       # 'pdf_acre3',
                                       # 'pdf_acre_type3', 
                                       # 'pdf_acre_term3',
                                       # 'pdf_acre4',
                                       # 'pdf_acre_type4', 
                                       # 'pdf_acre_term4',
                                       # 'pdf_acre5',
                                       # 'pdf_acre_type5', 
                                       # 'pdf_acre_term5', 
                                       # 'pdf_acre6',
                                       # 'pdf_acre_type6', 
                                       # 'pdf_acre_term6', 
                                       # 'pdf_lf1', 
                                       # 'pdf_lf_type1', 
                                       # 'pdf_ldf_term1', 
                                       # 'pdf_lf2', 
                                       # 'pdf_lf_type2', 
                                       # 'pdf_ldf_term2', 
                                       # 'pdf_lf3', 
                                       # 'pdf_lf_type3', 
                                       # 'pdf_ldf_term3', 
                                       "pdf_acre",
                                       "pdf_linear_feet",
                                       'pdf_text'])

# # Merge with RSS feed table
final_df = web_list_sub.join(pdf_df)

# Add a new column to track the number of errors for each webpage
final_df["error"] = final_df.apply(lambda row: row.str.contains("ERROR").sum(), axis = 1)

final_df
# Out:
#     Unnamed: 0                                           web_link  \
# 0            0  http://www.swg.usace.army.mil/Media/Public-Not...
# 1            1  http://www.swg.usace.army.mil/Media/Public-Not...
# 2            2  http://www.swg.usace.army.mil/Media/Public-Not...
# 3            3  http://www.swg.usace.army.mil/Media/Public-Not...
# 4            4  http://www.swg.usace.army.mil/Media/Public-Not...
# ..         ...                                                ...
# 95          95  http://www.swg.usace.army.mil/Media/Public-Not...
# 96          96  http://www.swg.usace.army.mil/Media/Public-Not...
# 97          97  http://www.swg.usace.army.mil/Media/Public-Not...
# 98          98  http://www.swg.usace.army.mil/Media/Public-Not...
# 99          99  http://www.swg.usace.army.mil/Media/Public-Not...
#
#                                             web_title published_date  \
# 0   SWG-1992-02709 - Cedar Marine Terminals (subsi...       9/5/2023
# ...

# %%
final_df.to_csv("galveston_subset.csv")
